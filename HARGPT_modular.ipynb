# %% [markdown]
# # HARGPT Modular Workflow
#
# This notebook keeps the original HARGPT workflow order, but the actual computation now lives under `scripts/`. The original `HARGPT.ipynb` remains unchanged for backtracking.

# %%
from pathlib import Path

from scripts.hargpt_pipeline_config import PipelineConfig
from scripts.hargpt_data import prepare_video_aligned_data, summarize_prepared_data
from scripts.hargpt_labels import build_weak_label_csv, summarize_weak_labels, plot_weak_label_overlay
from scripts.hargpt_prompts import generate_prompt_artifacts, summarize_prompt_artifacts
from scripts.hargpt_eval import evaluate_all_predictions

config = PipelineConfig(
    project_root=Path.cwd(),
    participant_no=24,
    video_name='GH040226',
    target_fs=50.0,
    window_seconds=2.0,
    stride_seconds=2.0,
    window_index_in_video_subset=0,
    prompt_window_count=400,
)
config
# Out:
# PipelineConfig(project_root=WindowsPath('G:/TUD_CESE/OneDrive - Delft University of Technology/Smart Cup/relativeWorks/hargpt_dir'), participant_no=24, video_name='GH040226', video_file=None, video_start_timecode=None, video_fps=None, force_regenerate_video_metadata=False, target_fs=50.0, window_seconds=2.0, stride_seconds=2.0, window_index_in_video_subset=0, prompt_window_count=400)

# %%
prepared = prepare_video_aligned_data(config)
summarize_prepared_data(prepared)
prepared.window_index_df.head()
# Out:
# Video file: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\videos\GH040226.mp4
# Video timecode CSV: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\videos\video_timecode_1HzGH040226.csv
# Video metadata JSON: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\videos\video_metadata_GH040226.json
# ACC video subset saved to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_acc_video_subset_65_GH040226.csv
# Window index saved to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_window_index_65_GH040226.csv
# Video range: 2025-07-17 13:57:00 -> 2025-07-17 14:08:47
# Video-subset windows: 353
#    window_id  start_idx_in_video_subset  end_idx_in_video_subset  \
# 0          0                          0                       99
# 1          1                        100                      199
# 2          2                        200                      299
# 3          3                        300                      399
# 4          4                        400                      499
#
#            start_time                end_time
# 0 2025-07-17 13:57:00 2025-07-17 13:57:01.980
# 1 2025-07-17 13:57:02 2025-07-17 13:57:03.980
# 2 2025-07-17 13:57:04 2025-07-17 13:57:05.980
# 3 2025-07-17 13:57:06 2025-07-17 13:57:07.980
# 4 2025-07-17 13:57:08 2025-07-17 13:57:09.980

# %%
acc_weak = build_weak_label_csv(prepared)
summarize_weak_labels(prepared, acc_weak)
acc_weak.head()
# Out:
# Weak label input: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\weak_label\24.json
# Weak label output: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\weak_label\weak_labels_65_GH040226.csv
# Video range: 2025-07-17 13:57:00 -> 2025-07-17 14:08:47
# ACC rows labeled: 35351
# weak_label
# Drinking      553
# Gesture     10223
# Nodding      3939
# Still       20544
# Toasting       92
# Name: count, dtype: int64
#                      time         x         y         z  state weak_label  \
# 0 2025-07-17 13:57:00.000 -0.079102 -0.051270 -1.019043      0      Still
# 1 2025-07-17 13:57:00.020 -0.080811 -0.041260 -1.022949      0      Still
# 2 2025-07-17 13:57:00.040 -0.092285 -0.051758 -1.022461      0      Still
# 3 2025-07-17 13:57:00.060 -0.084961 -0.048340 -1.016113      0      Still
# 4 2025-07-17 13:57:00.080 -0.084961 -0.043945 -1.006836      0      Still
#
#   video_name
# 0   GH040226
# 1   GH040226
# 2   GH040226
# 3   GH040226
# 4   GH040226

# %%
overlay_png = plot_weak_label_overlay(prepared, acc_weak)
print(f'Saved weak-label overlay plot to: {overlay_png}')
overlay_png
# Out:
# Saved weak-label overlay plot to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\weak_labels_overlay_65_GH040226.png
# WindowsPath('G:/TUD_CESE/OneDrive - Delft University of Technology/Smart Cup/relativeWorks/hargpt_dir/outputs/weak_labels_overlay_65_GH040226.png')

# %%
artifacts = generate_prompt_artifacts(prepared)
summarize_prompt_artifacts(artifacts)
artifacts.batch_dir
# Out:
# Prompt-style batch folder: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226
# Generated: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\window_data\xyz_only\hargpt_windows_0_to_352_65_GH040226_xyz_only.json
# Generated: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\prompts\xyz_only\hargpt_windows_0_to_352_65_GH040226_prompt_window_classification_xyz_only.txt
# Generated: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\window_data\xyz_tilt\hargpt_windows_0_to_352_65_GH040226_xyz_tilt.json
# Generated: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\prompts\xyz_tilt\hargpt_windows_0_to_352_65_GH040226_prompt_window_classification_xyz_tilt.txt
# Generated: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\window_data\xyz_RAG_tilt\hargpt_windows_0_to_352_65_GH040226_xyz_RAG_tilt.json
# Generated: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\prompts\xyz_RAG_tilt\hargpt_windows_0_to_352_65_GH040226_prompt_window_classification_xyz_RAG_tilt.txt
# Generated: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\window_data\xyz_only\hargpt_windows_0_to_352_65_GH040226_xyz_only.json
# Generated: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\prompts\xyz_only\hargpt_windows_0_to_352_65_GH040226_prompt_window_localization_xyz_only.txt
# Generated: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\window_data\xyz_tilt\hargpt_windows_0_to_352_65_GH040226_xyz_tilt.json
# Generated: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\prompts\xyz_tilt\hargpt_windows_0_to_352_65_GH040226_prompt_window_localization_xyz_tilt.txt
# Generated: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\window_data\xyz_RAG_tilt\hargpt_windows_0_to_352_65_GH040226_xyz_RAG_tilt.json
# Generated: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\prompts\xyz_RAG_tilt\hargpt_windows_0_to_352_65_GH040226_prompt_window_localization_xyz_RAG_tilt.txt
# WindowsPath('G:/TUD_CESE/OneDrive - Delft University of Technology/Smart Cup/relativeWorks/hargpt_dir/outputs/hargpt_windows_0_to_352_65_GH040226')

# %% [markdown]
# ## Manual Prediction Step
#
# Copy ChatGPT outputs into the appropriate folder under:
#
# - `outputs/<batch_name>/<prompt_style>/predictions/<feature_set>/`
#
# The evaluator below scans every prediction JSON under those folders.

# %%
plot_heads = evaluate_all_predictions(artifacts)
# Out:
# Using prediction JSON: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\predictions\xyz_only\chatgpt_65_4_24_8_45.json
# Saved comparison plot to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\predictions\xyz_only\chatgpt_65_4_24_8_45\comparison_vs_manual_labels.png
# Saved confusion counts to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\predictions\xyz_only\chatgpt_65_4_24_8_45\confusion_counts.csv
# Total accuracy = 10027 / 35300 = 0.284051
# Confusion matrix counts for original HARGPT / xyz_only / chatgpt_65_4_24_8_45.json:
#                  prediction:Still  prediction:Gesture  prediction:Drinking  \
# manual:Still                 4029                5444                 1525
# manual:Gesture                251                3222                 3296
# manual:Drinking                 0                  39                  514
# manual:Toasting                 0                  63                    0
# manual:Nodding               1275                 366                   65
#
#                  prediction:Toasting  prediction:Nodding
# manual:Still                     671                8824
# manual:Gesture                  1311                2143
# manual:Drinking                    0                   0
# manual:Toasting                   29                   0
# manual:Nodding                     0                2233
# Using prediction JSON: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\predictions\xyz_tilt\chatgpt_65_4_24_9_3.json
# Saved comparison plot to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\predictions\xyz_tilt\chatgpt_65_4_24_9_3\comparison_vs_manual_labels.png
# Saved confusion counts to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\predictions\xyz_tilt\chatgpt_65_4_24_9_3\confusion_counts.csv
# Total accuracy = 13047 / 35300 = 0.369603
# Confusion matrix counts for original HARGPT / xyz_tilt / chatgpt_65_4_24_9_3.json:
#                  prediction:Still  prediction:Gesture  prediction:Drinking  \
# manual:Still                 6967                5108                  924
# manual:Gesture                416                4940                    0
# manual:Drinking                 0                   0                  553
# manual:Toasting                 0                   0                   92
# manual:Nodding               2617                 552                  131
#
#                  prediction:Toasting  prediction:Nodding
# manual:Still                    1614                5880
# manual:Gesture                  2334                2533
# manual:Drinking                    0                   0
# manual:Toasting                    0                   0
# manual:Nodding                    52                 587
# Using prediction JSON: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\predictions\xyz_RAG_tilt\chatgpt_65_4_24_9_7.json
# Saved comparison plot to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\predictions\xyz_RAG_tilt\chatgpt_65_4_24_9_7\comparison_vs_manual_labels.png
# Saved confusion counts to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\original HARGPT\predictions\xyz_RAG_tilt\chatgpt_65_4_24_9_7\confusion_counts.csv
# Total accuracy = 13154 / 35300 = 0.372635
# Confusion matrix counts for original HARGPT / xyz_RAG_tilt / chatgpt_65_4_24_9_7.json:
#                  prediction:Still  prediction:Gesture  prediction:Drinking  \
# manual:Still                 2966                8742                  113
# manual:Gesture                162                7522                    0
# manual:Drinking                 0                  26                  498
# manual:Toasting                 0                   0                   38
# manual:Nodding                701                1080                   25
#
#                  prediction:Toasting  prediction:Nodding
# manual:Still                     961                7711
# manual:Gesture                  1065                1474
# manual:Drinking                   29                   0
# manual:Toasting                   54                   0
# manual:Nodding                    19                2114
# Using prediction JSON: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_only\chatgpt_65_4_24_9_16.json
# Saved comparison plot to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_only\chatgpt_65_4_24_9_16\comparison_vs_manual_labels.png
# Saved confusion counts to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_only\chatgpt_65_4_24_9_16\confusion_counts.csv
# Total accuracy = 13450 / 35300 = 0.381020
# Confusion matrix counts for Rule_based_localization / xyz_only / chatgpt_65_4_24_9_16.json:
#                  prediction:Still  prediction:Gesture  prediction:Drinking  \
# manual:Still                11348                1728                 4219
# manual:Gesture               2170                1653                 4480
# manual:Drinking                 0                 553                    0
# manual:Toasting                 0                  40                    0
# manual:Nodding               3315                 126                  101
#
#                  prediction:Toasting  prediction:Nodding
# manual:Still                    1516                1682
# manual:Gesture                  1332                 588
# manual:Drinking                    0                   0
# manual:Toasting                   52                   0
# manual:Nodding                     0                 397
# Using prediction JSON: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_only\chatgpt_65_4_24_9_42.json
# Saved comparison plot to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_only\chatgpt_65_4_24_9_42\comparison_vs_manual_labels.png
# Saved confusion counts to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_only\chatgpt_65_4_24_9_42\confusion_counts.csv
# Total accuracy = 16863 / 35300 = 0.477705
# Confusion matrix counts for Rule_based_localization / xyz_only / chatgpt_65_4_24_9_42.json:
#                  prediction:Still  prediction:Gesture  prediction:Drinking  \
# manual:Still                14290                2721                 1667
# manual:Gesture               5384                1608                 2297
# manual:Drinking                 0                   0                  553
# manual:Toasting                26                   0                   40
# manual:Nodding               3239                 171                  143
#
#                  prediction:Toasting  prediction:Nodding
# manual:Still                     370                1445
# manual:Gesture                   281                 653
# manual:Drinking                    0                   0
# manual:Toasting                   26                   0
# manual:Nodding                     0                 386
# Using prediction JSON: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_tilt\chat_65_4_21_19_08.json
# Saved comparison plot to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_tilt\chat_65_4_21_19_08\comparison_vs_manual_labels.png
# Saved confusion counts to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_tilt\chat_65_4_21_19_08\confusion_counts.csv
# Total accuracy = 19227 / 35300 = 0.544674
# Confusion matrix counts for Rule_based_localization / xyz_tilt / chat_65_4_21_19_08.json:
#                  prediction:Still  prediction:Gesture  prediction:Drinking  \
# manual:Still                12003                7760                  343
# manual:Gesture               3042                7105                    0
# manual:Drinking               100                   0                    0
# manual:Toasting                24                   0                   29
# manual:Nodding               3328                 481                   23
#
#                  prediction:Toasting  prediction:Nodding
# manual:Still                      75                 312
# manual:Gesture                     0                  76
# manual:Drinking                  453                   0
# manual:Toasting                   39                   0
# manual:Nodding                    27                  80
# Using prediction JSON: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_tilt\chatgpt_65_4_24_9_23.json
# Saved comparison plot to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_tilt\chatgpt_65_4_24_9_23\comparison_vs_manual_labels.png
# Saved confusion counts to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_tilt\chatgpt_65_4_24_9_23\confusion_counts.csv
# Total accuracy = 13086 / 35300 = 0.370708
# Confusion matrix counts for Rule_based_localization / xyz_tilt / chatgpt_65_4_24_9_23.json:
#                  prediction:Still  prediction:Gesture  prediction:Drinking  \
# manual:Still                10019                3913                 3966
# manual:Gesture               2286                1791                 5346
# manual:Drinking                 0                   0                  553
# manual:Toasting                 0                   0                   92
# manual:Nodding               2605                 468                  143
#
#                  prediction:Toasting  prediction:Nodding
# manual:Still                     434                2161
# manual:Gesture                   194                 606
# manual:Drinking                    0                   0
# manual:Toasting                    0                   0
# manual:Nodding                     0                 723
# Using prediction JSON: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_tilt\chatgpt_65_4_24_9_45.json
# Saved comparison plot to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_tilt\chatgpt_65_4_24_9_45\comparison_vs_manual_labels.png
# Saved confusion counts to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_tilt\chatgpt_65_4_24_9_45\confusion_counts.csv
# Total accuracy = 10287 / 35300 = 0.291416
# Confusion matrix counts for Rule_based_localization / xyz_tilt / chatgpt_65_4_24_9_45.json:
#                  prediction:Still  prediction:Gesture  prediction:Drinking  \
# manual:Still                 6199                6907                 4182
# manual:Gesture                272                3225                 5347
# manual:Drinking                 0                   0                  553
# manual:Toasting                 0                   0                   92
# manual:Nodding               1993                1468                  126
#
#                  prediction:Toasting  prediction:Nodding
# manual:Still                    2436                 769
# manual:Gesture                  1322                  57
# manual:Drinking                    0                   0
# manual:Toasting                    0                   0
# manual:Nodding                    42                 310
# Using prediction JSON: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_RAG_tilt\chat_65_4_24_9_28.json
# Saved comparison plot to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_RAG_tilt\chat_65_4_24_9_28\comparison_vs_manual_labels.png
# Saved confusion counts to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_RAG_tilt\chat_65_4_24_9_28\confusion_counts.csv
# Total accuracy = 8748 / 35300 = 0.247819
# Confusion matrix counts for Rule_based_localization / xyz_RAG_tilt / chat_65_4_24_9_28.json:
#                  prediction:Still  prediction:Gesture  prediction:Drinking  \
# manual:Still                 4309               10095                 5150
# manual:Gesture                167                3636                 5930
# manual:Drinking                 0                  25                  528
# manual:Toasting                 0                   0                   92
# manual:Nodding               1257                2229                  124
#
#                  prediction:Toasting  prediction:Nodding
# manual:Still                     499                 440
# manual:Gesture                   490                   0
# manual:Drinking                    0                   0
# manual:Toasting                    0                   0
# manual:Nodding                    54                 275
# Using prediction JSON: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_RAG_tilt\chat_65_4_24_9_50.json
# Saved comparison plot to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_RAG_tilt\chat_65_4_24_9_50\comparison_vs_manual_labels.png
# Saved confusion counts to: G:\TUD_CESE\OneDrive - Delft University of Technology\Smart Cup\relativeWorks\hargpt_dir\outputs\hargpt_windows_0_to_352_65_GH040226\Rule_based_localization\predictions\xyz_RAG_tilt\chat_65_4_24_9_50\confusion_counts.csv
# Total accuracy = 13700 / 35300 = 0.388102
# Confusion matrix counts for Rule_based_localization / xyz_RAG_tilt / chat_65_4_24_9_50.json:
#                  prediction:Still  prediction:Gesture  prediction:Drinking  \
# manual:Still                 7322                9432                 2096
# manual:Gesture                583                5198                 3945
# manual:Drinking                 0                   0                  553
# manual:Toasting                 0                   0                   92
# manual:Nodding               2427                 771                  114
#
#                  prediction:Toasting  prediction:Nodding
# manual:Still                     221                1422
# manual:Gesture                   275                 222
# manual:Drinking                    0                   0
# manual:Toasting                    0                   0
# manual:Nodding                     0                 627
